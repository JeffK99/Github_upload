# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Demo 9.5: Working with Text
# - Using [NLTK](http://www.nltk.org) (Natural Language Toolkit)
# - Using [spaCy](https://spacy.io)
#
# INSTRUCTIONS:
# - Run the cells
# - Observe and understand the results
# - Answer the questions

# %% [markdown]
# ## Import libraries

# %%
## Import Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter

import regex as re
import spacy
import nltk

# %% [markdown]
# ## Load data

# %%
## Loading the data

input_file = 'ncc-1701-D.txt'

with open(input_file, 'r') as f:
    ncc_text = f.read()

# %% [markdown]
# ## Inspect the data

# %%
print(ncc_text[:1000])
# Out:
# USS Enterprise (NCC-1701-D)
#
# "For five hundred years, every ship that has borne the name of the Enterprise has become a legend. This one is no different."
#
# The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise. During her career, the Enterprise served as the Federation flagship. The Enterprise was destroyed during the Battle of Veridian III in 2371.
#
# ==History==
# ===Construction and launch===
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system. The construction was a massive undertaking, involving thousands of people across disciplines. Construction was supervised by Commander Orfil Quinteros. Dr. Leah Brahms was responsible for much of the Enterprise's warp propulsion system design. Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus.
#
# One of the ship's nacelle tube was

# %% [markdown]
# ## Work the data
# - if necessary or desired
#     - remove text or content, e.g. quotes (") or metadata (===)
#     - add content or markers, e.g. (#FLAG, --NAME--)
#     - remove or convert special symbols, e.g. "é" to "e"
#     - remove or convert emoticons

# %%
# ANSWER
ncc_text = re.sub("[=']", '', ncc_text)
ncc_text = re.sub('[".(),;]','',ncc_text)
print(ncc_text)
# Out:
# USS Enterprise NCC-1701-D
#
# For five hundred years every ship that has borne the name of the Enterprise has become a legend This one is no different
#
# The USS Enterprise NCC-1701-D was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet and the fifth Federation ship to bear the name Enterprise During her career the Enterprise served as the Federation flagship The Enterprise was destroyed during the Battle of Veridian III in 2371
#
# History
# Construction and launch
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system The construction was a massive undertaking involving thousands of people across disciplines Construction was supervised by Commander Orfil Quinteros Dr Leah Brahms was responsible for much of the Enterprises warp propulsion system design Some of the Enterprises components were derived from technology originally developed on the USS Pegasus
#
# One of the ships nacelle tube was the site of a multiple murder-suicide while she was still under construction at Utopia Planitia A member of the construction team Walter Pierce became jealous of a former lovers new relationship He killed the two officers Marla Finn and William Hodges then disposed of their bodies in the plasma stream Pierce committed suicide in the same manner leaving a telepathic imprint in a bulkhead that was not discovered until 2370
#
# On stardate 407595 in the year 2363 the Enterprise was launched from Mars On stardate 410255 the Enterprise was commissioned
#
# These stardates werent mentioned in dialog they were from the Enterprise dedication plaque
#
# Final systems completion and shakedown was conducted at Earth Station McKinley Captain Jean-Luc Picard took command of the ship on stardate 41148 at the order of Rear Admiral Norah Satie
#
# Legacy
# Commander Riker was upset over the loss of the Enterprise Having hoped he would one day command the ship he was disappointed that he never got that opportunity However Picard expressed doubt that the Enterprise-D would be the last vessel to carry the name
#
# The Enterprise was so dear to Worf that shortly after being reassigned to Deep Space 9 in 2372 he briefly considered resigning from Starfleet Station commander Captain Benjamin Sisko expressed regret on the loss of the Enterprise and offered his condolences over the destruction of the ship to Worf saying the Enterprise was a good ship
#
# Captain Picards belief that the Enterprise-D would not be the final ship to bear the name was borne out with the christening of the Class Sovereign USS Enterprise NCC-1701-E later the same year In that instance the legacy of the Enterprise continued with Picard reprising his role as CO and selecting most of the former crew from the Enterprise-D with the notable exception of Worf due to his most recent assignment to DS9 though he temporarily joined the Enterprise-E crew on several of their more notable missions

# %% [markdown]
# ## Helper method

# %%
# create a bar chart of the frequency of the words in the text
def plot_words(tokens, top = 30):
    tokens_counter = Counter(tokens)
    tok = [t for (t, _) in tokens_counter.most_common()]
    val = [v for (_, v) in tokens_counter.most_common()]

    plt.figure(figsize = (16, 6))
    plt.bar(tok[:top], val[:top])
    plt.title('Number of terms: %d' % len(tokens_counter))
    plt.xticks(rotation = 90)

    plt.show()

# %% [markdown]
# ## spaCy model invocation and text processing
# spaCy does the processing of the text as part of the reading of the data.

# %%
# load spaCy and the English model
nlp = spacy.load('en')

# process the text
nlp_text = nlp(ncc_text)

# %% [markdown]
# ## Tokenise

# %%
# only show the results
# spaCy has done it already
for i, t in enumerate(nlp_text):
    print('%2d| %r' % (i+1, t.text))
    if t.text == '.':
        break
# Out:
#  1| 'USS'
#  2| 'Enterprise'
#  3| 'NCC-1701-D'
#  4| '\n\n'
#  5| 'For'
#  6| 'five'
#  7| 'hundred'
#  8| 'years'
#  9| 'every'
# 10| 'ship'
# 11| 'that'
# 12| 'has'
# 13| 'borne'
# 14| 'the'
# 15| 'name'
# 16| 'of'
# 17| 'the'
# 18| 'Enterprise'
# 19| 'has'
# 20| 'become'
# 21| 'a'
# 22| 'legend'
# 23| 'This'
# 24| 'one'
# 25| 'is'
# 26| 'no'
# 27| 'different'
# 28| '\n\n'
# 29| 'The'
# 30| 'USS'
# 31| 'Enterprise'
# 32| 'NCC-1701-D'
# 33| 'was'
# 34| 'a'
# 35| '24th'
# 36| 'century'
# 37| 'United'
# 38| 'Federation'
# 39| 'of'
# 40| 'Planets'
# 41| 'Galaxy'
# 42| 'Class'
# 43| 'starship'
# 44| 'operated'
# 45| 'by'
# 46| 'Starfleet'
# 47| 'and'
# 48| 'the'
# 49| 'fifth'
# 50| 'Federation'
# 51| 'ship'
# 52| 'to'
# 53| 'bear'
# 54| 'the'
# 55| 'name'
# 56| 'Enterprise'
# 57| 'During'
# 58| 'her'
# 59| 'career'
# 60| 'the'
# 61| 'Enterprise'
# 62| 'served'
# 63| 'as'
# 64| 'the'
# 65| 'Federation'
# 66| 'flagship'
# 67| 'The'
# 68| 'Enterprise'
# 69| 'was'
# 70| 'destroyed'
# 71| 'during'
# 72| 'the'
# 73| 'Battle'
# 74| 'of'
# 75| 'Veridian'
# 76| 'III'
# 77| 'in'
# 78| '2371'
# 79| '\n\n'
# 80| 'History'
# 81| '\n'
# 82| 'Construction'
# 83| 'and'
# 84| 'launch'
# 85| '\n'
# 86| 'The'
# 87| 'Enterprise'
# 88| 'was'
# 89| 'built'
# 90| 'at'
# 91| 'Utopia'
# 92| 'Planitia'
# 93| 'Fleet'
# 94| 'Yards'
# 95| 'orbiting'
# 96| 'Mars'
# 97| 'in'
# 98| 'the'
# 99| 'Solar'
# 100| 'system'
# 101| 'The'
# 102| 'construction'
# 103| 'was'
# 104| 'a'
# 105| 'massive'
# 106| 'undertaking'
# 107| 'involving'
# 108| 'thousands'
# 109| 'of'
# 110| 'people'
# 111| 'across'
# 112| 'disciplines'
# 113| 'Construction'
# 114| 'was'
# 115| 'supervised'
# 116| 'by'
# 117| 'Commander'
# 118| 'Orfil'
# 119| 'Quinteros'
# 120| 'Dr'
# 121| 'Leah'
# 122| 'Brahms'
# 123| 'was'
# 124| 'responsible'
# 125| 'for'
# 126| 'much'
# 127| 'of'
# 128| 'the'
# 129| 'Enterprises'
# 130| 'warp'
# 131| 'propulsion'
# 132| 'system'
# 133| 'design'
# 134| 'Some'
# 135| 'of'
# 136| 'the'
# 137| 'Enterprises'
# 138| 'components'
# 139| 'were'
# 140| 'derived'
# 141| 'from'
# 142| 'technology'
# 143| 'originally'
# 144| 'developed'
# 145| 'on'
# 146| 'the'
# 147| 'USS'
# 148| 'Pegasus'
# 149| '\n\n'
# 150| 'One'
# 151| 'of'
# 152| 'the'
# 153| 'ships'
# 154| 'nacelle'
# 155| 'tube'
# 156| 'was'
# 157| 'the'
# 158| 'site'
# 159| 'of'
# 160| 'a'
# 161| 'multiple'
# 162| 'murder'
# 163| '-'
# 164| 'suicide'
# 165| 'while'
# 166| 'she'
# 167| 'was'
# 168| 'still'
# 169| 'under'
# 170| 'construction'
# 171| 'at'
# 172| 'Utopia'
# 173| 'Planitia'
# 174| 'A'
# 175| 'member'
# 176| 'of'
# 177| 'the'
# 178| 'construction'
# 179| 'team'
# 180| 'Walter'
# 181| 'Pierce'
# 182| 'became'
# 183| 'jealous'
# 184| 'of'
# 185| 'a'
# 186| 'former'
# 187| 'lovers'
# 188| 'new'
# 189| 'relationship'
# 190| 'He'
# 191| 'killed'
# 192| 'the'
# 193| 'two'
# 194| 'officers'
# 195| 'Marla'
# 196| 'Finn'
# 197| 'and'
# 198| 'William'
# 199| 'Hodges'
# 200| 'then'
# 201| 'disposed'
# 202| 'of'
# 203| 'their'
# 204| 'bodies'
# 205| 'in'
# 206| 'the'
# 207| 'plasma'
# 208| 'stream'
# 209| 'Pierce'
# 210| 'committed'
# 211| 'suicide'
# 212| 'in'
# 213| 'the'
# 214| 'same'
# 215| 'manner'
# 216| 'leaving'
# 217| 'a'
# 218| 'telepathic'
# 219| 'imprint'
# 220| 'in'
# 221| 'a'
# 222| 'bulkhead'
# 223| 'that'
# 224| 'was'
# 225| 'not'
# 226| 'discovered'
# 227| 'until'
# 228| '2370'
# 229| '\n\n'
# 230| 'On'
# 231| 'stardate'
# 232| '407595'
# 233| 'in'
# 234| 'the'
# 235| 'year'
# 236| '2363'
# 237| 'the'
# 238| 'Enterprise'
# 239| 'was'
# 240| 'launched'
# 241| 'from'
# 242| 'Mars'
# 243| 'On'
# 244| 'stardate'
# 245| '410255'
# 246| 'the'
# 247| 'Enterprise'
# 248| 'was'
# 249| 'commissioned'
# 250| '\n\n'
# 251| 'These'
# 252| 'stardates'
# 253| 'were'
# 254| 'nt'
# 255| 'mentioned'
# 256| 'in'
# 257| 'dialog'
# 258| 'they'
# 259| 'were'
# 260| 'from'
# 261| 'the'
# 262| 'Enterprise'
# 263| 'dedication'
# 264| 'plaque'
# 265| '\n\n'
# 266| 'Final'
# 267| 'systems'
# 268| 'completion'
# 269| 'and'
# 270| 'shakedown'
# 271| 'was'
# 272| 'conducted'
# 273| 'at'
# 274| 'Earth'
# 275| 'Station'
# 276| 'McKinley'
# 277| 'Captain'
# 278| 'Jean'
# 279| '-'
# 280| 'Luc'
# 281| 'Picard'
# 282| 'took'
# 283| 'command'
# 284| 'of'
# 285| 'the'
# 286| 'ship'
# 287| 'on'
# 288| 'stardate'
# 289| '41148'
# 290| 'at'
# 291| 'the'
# 292| 'order'
# 293| 'of'
# 294| 'Rear'
# 295| 'Admiral'
# 296| 'Norah'
# 297| 'Satie'
# 298| '\n\n'
# 299| 'Legacy'
# 300| '\n'
# 301| 'Commander'
# 302| 'Riker'
# 303| 'was'
# 304| 'upset'
# 305| 'over'
# 306| 'the'
# 307| 'loss'
# 308| 'of'
# 309| 'the'
# 310| 'Enterprise'
# 311| 'Having'
# 312| 'hoped'
# 313| 'he'
# 314| 'would'
# 315| 'one'
# 316| 'day'
# 317| 'command'
# 318| 'the'
# 319| 'ship'
# 320| 'he'
# 321| 'was'
# 322| 'disappointed'
# 323| 'that'
# 324| 'he'
# 325| 'never'
# 326| 'got'
# 327| 'that'
# 328| 'opportunity'
# 329| 'However'
# 330| 'Picard'
# 331| 'expressed'
# 332| 'doubt'
# 333| 'that'
# 334| 'the'
# 335| 'Enterprise'
# 336| '-'
# 337| 'D'
# 338| 'would'
# 339| 'be'
# 340| 'the'
# 341| 'last'
# 342| 'vessel'
# 343| 'to'
# 344| 'carry'
# 345| 'the'
# 346| 'name'
# 347| '\n\n'
# 348| 'The'
# 349| 'Enterprise'
# 350| 'was'
# 351| 'so'
# 352| 'dear'
# 353| 'to'
# 354| 'Worf'
# 355| 'that'
# 356| 'shortly'
# 357| 'after'
# 358| 'being'
# 359| 'reassigned'
# 360| 'to'
# 361| 'Deep'
# 362| 'Space'
# 363| '9'
# 364| 'in'
# 365| '2372'
# 366| 'he'
# 367| 'briefly'
# 368| 'considered'
# 369| 'resigning'
# 370| 'from'
# 371| 'Starfleet'
# 372| 'Station'
# 373| 'commander'
# 374| 'Captain'
# 375| 'Benjamin'
# 376| 'Sisko'
# 377| 'expressed'
# 378| 'regret'
# 379| 'on'
# 380| 'the'
# 381| 'loss'
# 382| 'of'
# 383| 'the'
# 384| 'Enterprise'
# 385| 'and'
# 386| 'offered'
# 387| 'his'
# 388| 'condolences'
# 389| 'over'
# 390| 'the'
# 391| 'destruction'
# 392| 'of'
# 393| 'the'
# 394| 'ship'
# 395| 'to'
# 396| 'Worf'
# 397| 'saying'
# 398| 'the'
# 399| 'Enterprise'
# 400| 'was'
# 401| 'a'
# 402| 'good'
# 403| 'ship'
# 404| '\n\n'
# 405| 'Captain'
# 406| 'Picards'
# 407| 'belief'
# 408| 'that'
# 409| 'the'
# 410| 'Enterprise'
# 411| '-'
# 412| 'D'
# 413| 'would'
# 414| 'not'
# 415| 'be'
# 416| 'the'
# 417| 'final'
# 418| 'ship'
# 419| 'to'
# 420| 'bear'
# 421| 'the'
# 422| 'name'
# 423| 'was'
# 424| 'borne'
# 425| 'out'
# 426| 'with'
# 427| 'the'
# 428| 'christening'
# 429| 'of'
# 430| 'the'
# 431| 'Class'
# 432| 'Sovereign'
# 433| 'USS'
# 434| 'Enterprise'
# 435| 'NCC-1701-E'
# 436| 'later'
# 437| 'the'
# 438| 'same'
# 439| 'year'
# 440| 'In'
# 441| 'that'
# 442| 'instance'
# 443| 'the'
# 444| 'legacy'
# 445| 'of'
# 446| 'the'
# 447| 'Enterprise'
# 448| 'continued'
# 449| 'with'
# 450| 'Picard'
# 451| 'reprising'
# 452| 'his'
# 453| 'role'
# 454| 'as'
# 455| 'CO'
# 456| 'and'
# 457| 'selecting'
# 458| 'most'
# 459| 'of'
# 460| 'the'
# 461| 'former'
# 462| 'crew'
# 463| 'from'
# 464| 'the'
# 465| 'Enterprise'
# 466| '-'
# 467| 'D'
# 468| 'with'
# 469| 'the'
# 470| 'notable'
# 471| 'exception'
# 472| 'of'
# 473| 'Worf'
# 474| 'due'
# 475| 'to'
# 476| 'his'
# 477| 'most'
# 478| 'recent'
# 479| 'assignment'
# 480| 'to'
# 481| 'DS9'
# 482| 'though'
# 483| 'he'
# 484| 'temporarily'
# 485| 'joined'
# 486| 'the'
# 487| 'Enterprise'
# 488| '-'
# 489| 'E'
# 490| 'crew'
# 491| 'on'
# 492| 'several'
# 493| 'of'
# 494| 'their'
# 495| 'more'
# 496| 'notable'
# 497| 'missions'

# %%
# ANSWER

# %% [markdown]
# ### Stop Words

# %%
## spaCy
print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
for i, t in enumerate(nlp_text):
    print('%2d| %-15r %r' % (i+1, t.text, ('' if t.is_stop else t.text)))

    # break after the first sentence
    if t.text == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'           'USS'
#  2| 'Enterprise'    'Enterprise'
#  3| 'NCC-1701-D'    'NCC-1701-D'
#  4| '\n\n'          '\n\n'
#  5| 'For'           ''
#  6| 'five'          ''
#  7| 'hundred'       ''
#  8| 'years'         'years'
#  9| 'every'         ''
# 10| 'ship'          'ship'
# 11| 'that'          ''
# 12| 'has'           ''
# 13| 'borne'         'borne'
# 14| 'the'           ''
# 15| 'name'          ''
# 16| 'of'            ''
# 17| 'the'           ''
# 18| 'Enterprise'    'Enterprise'
# 19| 'has'           ''
# 20| 'become'        ''
# 21| 'a'             ''
# 22| 'legend'        'legend'
# 23| 'This'          ''
# 24| 'one'           ''
# 25| 'is'            ''
# 26| 'no'            ''
# 27| 'different'     'different'
# 28| '\n\n'          '\n\n'
# 29| 'The'           ''
# 30| 'USS'           'USS'
# 31| 'Enterprise'    'Enterprise'
# 32| 'NCC-1701-D'    'NCC-1701-D'
# 33| 'was'           ''
# 34| 'a'             ''
# 35| '24th'          '24th'
# 36| 'century'       'century'
# 37| 'United'        'United'
# 38| 'Federation'    'Federation'
# 39| 'of'            ''
# 40| 'Planets'       'Planets'
# 41| 'Galaxy'        'Galaxy'
# 42| 'Class'         'Class'
# 43| 'starship'      'starship'
# 44| 'operated'      'operated'
# 45| 'by'            ''
# 46| 'Starfleet'     'Starfleet'
# 47| 'and'           ''
# 48| 'the'           ''
# 49| 'fifth'         'fifth'
# 50| 'Federation'    'Federation'
# 51| 'ship'          'ship'
# 52| 'to'            ''
# 53| 'bear'          'bear'
# 54| 'the'           ''
# 55| 'name'          ''
# 56| 'Enterprise'    'Enterprise'
# 57| 'During'        ''
# 58| 'her'           ''
# 59| 'career'        'career'
# 60| 'the'           ''
# 61| 'Enterprise'    'Enterprise'
# 62| 'served'        'served'
# 63| 'as'            ''
# 64| 'the'           ''
# 65| 'Federation'    'Federation'
# 66| 'flagship'      'flagship'
# 67| 'The'           ''
# 68| 'Enterprise'    'Enterprise'
# 69| 'was'           ''
# 70| 'destroyed'     'destroyed'
# 71| 'during'        ''
# 72| 'the'           ''
# 73| 'Battle'        'Battle'
# 74| 'of'            ''
# 75| 'Veridian'      'Veridian'
# 76| 'III'           'III'
# 77| 'in'            ''
# 78| '2371'          '2371'
# 79| '\n\n'          '\n\n'
# 80| 'History'       'History'
# 81| '\n'            '\n'
# 82| 'Construction'  'Construction'
# 83| 'and'           ''
# 84| 'launch'        'launch'
# 85| '\n'            '\n'
# 86| 'The'           ''
# 87| 'Enterprise'    'Enterprise'
# 88| 'was'           ''
# 89| 'built'         'built'
# 90| 'at'            ''
# 91| 'Utopia'        'Utopia'
# 92| 'Planitia'      'Planitia'
# 93| 'Fleet'         'Fleet'
# 94| 'Yards'         'Yards'
# 95| 'orbiting'      'orbiting'
# 96| 'Mars'          'Mars'
# 97| 'in'            ''
# 98| 'the'           ''
# 99| 'Solar'         'Solar'
# 100| 'system'        'system'
# 101| 'The'           ''
# 102| 'construction'  'construction'
# 103| 'was'           ''
# 104| 'a'             ''
# 105| 'massive'       'massive'
# 106| 'undertaking'   'undertaking'
# 107| 'involving'     'involving'
# 108| 'thousands'     'thousands'
# 109| 'of'            ''
# 110| 'people'        'people'
# 111| 'across'        ''
# 112| 'disciplines'   'disciplines'
# 113| 'Construction'  'Construction'
# 114| 'was'           ''
# 115| 'supervised'    'supervised'
# 116| 'by'            ''
# 117| 'Commander'     'Commander'
# 118| 'Orfil'         'Orfil'
# 119| 'Quinteros'     'Quinteros'
# 120| 'Dr'            'Dr'
# 121| 'Leah'          'Leah'
# 122| 'Brahms'        'Brahms'
# 123| 'was'           ''
# 124| 'responsible'   'responsible'
# 125| 'for'           ''
# 126| 'much'          ''
# 127| 'of'            ''
# 128| 'the'           ''
# 129| 'Enterprises'   'Enterprises'
# 130| 'warp'          'warp'
# 131| 'propulsion'    'propulsion'
# 132| 'system'        'system'
# 133| 'design'        'design'
# 134| 'Some'          ''
# 135| 'of'            ''
# 136| 'the'           ''
# 137| 'Enterprises'   'Enterprises'
# 138| 'components'    'components'
# 139| 'were'          ''
# 140| 'derived'       'derived'
# 141| 'from'          ''
# 142| 'technology'    'technology'
# 143| 'originally'    'originally'
# 144| 'developed'     'developed'
# 145| 'on'            ''
# 146| 'the'           ''
# 147| 'USS'           'USS'
# 148| 'Pegasus'       'Pegasus'
# 149| '\n\n'          '\n\n'
# 150| 'One'           ''
# 151| 'of'            ''
# 152| 'the'           ''
# 153| 'ships'         'ships'
# 154| 'nacelle'       'nacelle'
# 155| 'tube'          'tube'
# 156| 'was'           ''
# 157| 'the'           ''
# 158| 'site'          'site'
# 159| 'of'            ''
# 160| 'a'             ''
# 161| 'multiple'      'multiple'
# 162| 'murder'        'murder'
# 163| '-'             '-'
# 164| 'suicide'       'suicide'
# 165| 'while'         ''
# 166| 'she'           ''
# 167| 'was'           ''
# 168| 'still'         ''
# 169| 'under'         ''
# 170| 'construction'  'construction'
# 171| 'at'            ''
# 172| 'Utopia'        'Utopia'
# 173| 'Planitia'      'Planitia'
# 174| 'A'             ''
# 175| 'member'        'member'
# 176| 'of'            ''
# 177| 'the'           ''
# 178| 'construction'  'construction'
# 179| 'team'          'team'
# 180| 'Walter'        'Walter'
# 181| 'Pierce'        'Pierce'
# 182| 'became'        ''
# 183| 'jealous'       'jealous'
# 184| 'of'            ''
# 185| 'a'             ''
# 186| 'former'        ''
# 187| 'lovers'        'lovers'
# 188| 'new'           'new'
# 189| 'relationship'  'relationship'
# 190| 'He'            ''
# 191| 'killed'        'killed'
# 192| 'the'           ''
# 193| 'two'           ''
# 194| 'officers'      'officers'
# 195| 'Marla'         'Marla'
# 196| 'Finn'          'Finn'
# 197| 'and'           ''
# 198| 'William'       'William'
# 199| 'Hodges'        'Hodges'
# 200| 'then'          ''
# 201| 'disposed'      'disposed'
# 202| 'of'            ''
# 203| 'their'         ''
# 204| 'bodies'        'bodies'
# 205| 'in'            ''
# 206| 'the'           ''
# 207| 'plasma'        'plasma'
# 208| 'stream'        'stream'
# 209| 'Pierce'        'Pierce'
# 210| 'committed'     'committed'
# 211| 'suicide'       'suicide'
# 212| 'in'            ''
# 213| 'the'           ''
# 214| 'same'          ''
# 215| 'manner'        'manner'
# 216| 'leaving'       'leaving'
# 217| 'a'             ''
# 218| 'telepathic'    'telepathic'
# 219| 'imprint'       'imprint'
# 220| 'in'            ''
# 221| 'a'             ''
# 222| 'bulkhead'      'bulkhead'
# 223| 'that'          ''
# 224| 'was'           ''
# 225| 'not'           ''
# 226| 'discovered'    'discovered'
# 227| 'until'         ''
# 228| '2370'          '2370'
# 229| '\n\n'          '\n\n'
# 230| 'On'            ''
# 231| 'stardate'      'stardate'
# 232| '407595'        '407595'
# 233| 'in'            ''
# 234| 'the'           ''
# 235| 'year'          'year'
# 236| '2363'          '2363'
# 237| 'the'           ''
# 238| 'Enterprise'    'Enterprise'
# 239| 'was'           ''
# 240| 'launched'      'launched'
# 241| 'from'          ''
# 242| 'Mars'          'Mars'
# 243| 'On'            ''
# 244| 'stardate'      'stardate'
# 245| '410255'        '410255'
# 246| 'the'           ''
# 247| 'Enterprise'    'Enterprise'
# 248| 'was'           ''
# 249| 'commissioned'  'commissioned'
# 250| '\n\n'          '\n\n'
# 251| 'These'         ''
# 252| 'stardates'     'stardates'
# 253| 'were'          ''
# 254| 'nt'            'nt'
# 255| 'mentioned'     'mentioned'
# 256| 'in'            ''
# 257| 'dialog'        'dialog'
# 258| 'they'          ''
# 259| 'were'          ''
# 260| 'from'          ''
# 261| 'the'           ''
# 262| 'Enterprise'    'Enterprise'
# 263| 'dedication'    'dedication'
# 264| 'plaque'        'plaque'
# 265| '\n\n'          '\n\n'
# 266| 'Final'         'Final'
# 267| 'systems'       'systems'
# 268| 'completion'    'completion'
# 269| 'and'           ''
# 270| 'shakedown'     'shakedown'
# 271| 'was'           ''
# 272| 'conducted'     'conducted'
# 273| 'at'            ''
# 274| 'Earth'         'Earth'
# 275| 'Station'       'Station'
# 276| 'McKinley'      'McKinley'
# 277| 'Captain'       'Captain'
# 278| 'Jean'          'Jean'
# 279| '-'             '-'
# 280| 'Luc'           'Luc'
# 281| 'Picard'        'Picard'
# 282| 'took'          'took'
# 283| 'command'       'command'
# 284| 'of'            ''
# 285| 'the'           ''
# 286| 'ship'          'ship'
# 287| 'on'            ''
# 288| 'stardate'      'stardate'
# 289| '41148'         '41148'
# 290| 'at'            ''
# 291| 'the'           ''
# 292| 'order'         'order'
# 293| 'of'            ''
# 294| 'Rear'          'Rear'
# 295| 'Admiral'       'Admiral'
# 296| 'Norah'         'Norah'
# 297| 'Satie'         'Satie'
# 298| '\n\n'          '\n\n'
# 299| 'Legacy'        'Legacy'
# 300| '\n'            '\n'
# 301| 'Commander'     'Commander'
# 302| 'Riker'         'Riker'
# 303| 'was'           ''
# 304| 'upset'         'upset'
# 305| 'over'          ''
# 306| 'the'           ''
# 307| 'loss'          'loss'
# 308| 'of'            ''
# 309| 'the'           ''
# 310| 'Enterprise'    'Enterprise'
# 311| 'Having'        'Having'
# 312| 'hoped'         'hoped'
# 313| 'he'            ''
# 314| 'would'         ''
# 315| 'one'           ''
# 316| 'day'           'day'
# 317| 'command'       'command'
# 318| 'the'           ''
# 319| 'ship'          'ship'
# 320| 'he'            ''
# 321| 'was'           ''
# 322| 'disappointed'  'disappointed'
# 323| 'that'          ''
# 324| 'he'            ''
# 325| 'never'         ''
# 326| 'got'           'got'
# 327| 'that'          ''
# 328| 'opportunity'   'opportunity'
# 329| 'However'       ''
# 330| 'Picard'        'Picard'
# 331| 'expressed'     'expressed'
# 332| 'doubt'         'doubt'
# 333| 'that'          ''
# 334| 'the'           ''
# 335| 'Enterprise'    'Enterprise'
# 336| '-'             '-'
# 337| 'D'             'D'
# 338| 'would'         ''
# 339| 'be'            ''
# 340| 'the'           ''
# 341| 'last'          ''
# 342| 'vessel'        'vessel'
# 343| 'to'            ''
# 344| 'carry'         'carry'
# 345| 'the'           ''
# 346| 'name'          ''
# 347| '\n\n'          '\n\n'
# 348| 'The'           ''
# 349| 'Enterprise'    'Enterprise'
# 350| 'was'           ''
# 351| 'so'            ''
# 352| 'dear'          'dear'
# 353| 'to'            ''
# 354| 'Worf'          'Worf'
# 355| 'that'          ''
# 356| 'shortly'       'shortly'
# 357| 'after'         ''
# 358| 'being'         ''
# 359| 'reassigned'    'reassigned'
# 360| 'to'            ''
# 361| 'Deep'          'Deep'
# 362| 'Space'         'Space'
# 363| '9'             '9'
# 364| 'in'            ''
# 365| '2372'          '2372'
# 366| 'he'            ''
# 367| 'briefly'       'briefly'
# 368| 'considered'    'considered'
# 369| 'resigning'     'resigning'
# 370| 'from'          ''
# 371| 'Starfleet'     'Starfleet'
# 372| 'Station'       'Station'
# 373| 'commander'     'commander'
# 374| 'Captain'       'Captain'
# 375| 'Benjamin'      'Benjamin'
# 376| 'Sisko'         'Sisko'
# 377| 'expressed'     'expressed'
# 378| 'regret'        'regret'
# 379| 'on'            ''
# 380| 'the'           ''
# 381| 'loss'          'loss'
# 382| 'of'            ''
# 383| 'the'           ''
# 384| 'Enterprise'    'Enterprise'
# 385| 'and'           ''
# 386| 'offered'       'offered'
# 387| 'his'           ''
# 388| 'condolences'   'condolences'
# 389| 'over'          ''
# 390| 'the'           ''
# 391| 'destruction'   'destruction'
# 392| 'of'            ''
# 393| 'the'           ''
# 394| 'ship'          'ship'
# 395| 'to'            ''
# 396| 'Worf'          'Worf'
# 397| 'saying'        'saying'
# 398| 'the'           ''
# 399| 'Enterprise'    'Enterprise'
# 400| 'was'           ''
# 401| 'a'             ''
# 402| 'good'          'good'
# 403| 'ship'          'ship'
# 404| '\n\n'          '\n\n'
# 405| 'Captain'       'Captain'
# 406| 'Picards'       'Picards'
# 407| 'belief'        'belief'
# 408| 'that'          ''
# 409| 'the'           ''
# 410| 'Enterprise'    'Enterprise'
# 411| '-'             '-'
# 412| 'D'             'D'
# 413| 'would'         ''
# 414| 'not'           ''
# 415| 'be'            ''
# 416| 'the'           ''
# 417| 'final'         'final'
# 418| 'ship'          'ship'
# 419| 'to'            ''
# 420| 'bear'          'bear'
# 421| 'the'           ''
# 422| 'name'          ''
# 423| 'was'           ''
# 424| 'borne'         'borne'
# 425| 'out'           ''
# 426| 'with'          ''
# 427| 'the'           ''
# 428| 'christening'   'christening'
# 429| 'of'            ''
# 430| 'the'           ''
# 431| 'Class'         'Class'
# 432| 'Sovereign'     'Sovereign'
# 433| 'USS'           'USS'
# 434| 'Enterprise'    'Enterprise'
# 435| 'NCC-1701-E'    'NCC-1701-E'
# 436| 'later'         'later'
# 437| 'the'           ''
# 438| 'same'          ''
# 439| 'year'          'year'
# 440| 'In'            ''
# 441| 'that'          ''
# 442| 'instance'      'instance'
# 443| 'the'           ''
# 444| 'legacy'        'legacy'
# 445| 'of'            ''
# 446| 'the'           ''
# 447| 'Enterprise'    'Enterprise'
# 448| 'continued'     'continued'
# 449| 'with'          ''
# 450| 'Picard'        'Picard'
# 451| 'reprising'     'reprising'
# 452| 'his'           ''
# 453| 'role'          'role'
# 454| 'as'            ''
# 455| 'CO'            'CO'
# 456| 'and'           ''
# 457| 'selecting'     'selecting'
# 458| 'most'          ''
# 459| 'of'            ''
# 460| 'the'           ''
# 461| 'former'        ''
# 462| 'crew'          'crew'
# 463| 'from'          ''
# 464| 'the'           ''
# 465| 'Enterprise'    'Enterprise'
# 466| '-'             '-'
# 467| 'D'             'D'
# 468| 'with'          ''
# 469| 'the'           ''
# 470| 'notable'       'notable'
# 471| 'exception'     'exception'
# 472| 'of'            ''
# 473| 'Worf'          'Worf'
# 474| 'due'           ''
# 475| 'to'            ''
# 476| 'his'           ''
# 477| 'most'          ''
# 478| 'recent'        'recent'
# 479| 'assignment'    'assignment'
# 480| 'to'            ''
# 481| 'DS9'           'DS9'
# 482| 'though'        ''
# 483| 'he'            ''
# 484| 'temporarily'   'temporarily'
# 485| 'joined'        'joined'
# 486| 'the'           ''
# 487| 'Enterprise'    'Enterprise'
# 488| '-'             '-'
# 489| 'E'             'E'
# 490| 'crew'          'crew'
# 491| 'on'            ''
# 492| 'several'       ''
# 493| 'of'            ''
# 494| 'their'         ''
# 495| 'more'          ''
# 496| 'notable'       'notable'
# 497| 'missions'      'missions'

# %%
plot_words(['%r' % t.text for t in doc if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Check Part of Speech

# %%
## spaCy
for i, t in enumerate(nlp_text):
    print('%2d|%-12r : %-5s %s' % (i+1, t.text, t.pos_, t.tag_))
    if t.text == '.':
        break
# Out:
#  1|'USS'        : PROPN NNP
#  2|'Enterprise' : PROPN NNP
#  3|'NCC-1701-D' : PROPN NNP
#  4|'\n\n'       : SPACE _SP
#  5|'For'        : ADP   IN
#  6|'five'       : NUM   CD
#  7|'hundred'    : NUM   CD
#  8|'years'      : NOUN  NNS
#  9|'every'      : DET   DT
# 10|'ship'       : NOUN  NN
# 11|'that'       : DET   WDT
# 12|'has'        : AUX   VBZ
# 13|'borne'      : VERB  VBN
# 14|'the'        : DET   DT
# 15|'name'       : NOUN  NN
# 16|'of'         : ADP   IN
# 17|'the'        : DET   DT
# 18|'Enterprise' : NOUN  NN
# 19|'has'        : AUX   VBZ
# 20|'become'     : VERB  VBN
# 21|'a'          : DET   DT
# 22|'legend'     : NOUN  NN
# 23|'This'       : DET   DT
# 24|'one'        : NOUN  NN
# 25|'is'         : AUX   VBZ
# 26|'no'         : ADV   RB
# 27|'different'  : ADJ   JJ
# 28|'\n\n'       : SPACE _SP
# 29|'The'        : DET   DT
# 30|'USS'        : PROPN NNP
# 31|'Enterprise' : PROPN NNP
# 32|'NCC-1701-D' : PROPN NNP
# 33|'was'        : AUX   VBD
# 34|'a'          : DET   DT
# 35|'24th'       : ADJ   JJ
# 36|'century'    : NOUN  NN
# 37|'United'     : PROPN NNP
# 38|'Federation' : PROPN NNP
# 39|'of'         : ADP   IN
# 40|'Planets'    : PROPN NNP
# 41|'Galaxy'     : PROPN NNP
# 42|'Class'      : PROPN NNP
# 43|'starship'   : NOUN  NN
# 44|'operated'   : VERB  VBN
# 45|'by'         : ADP   IN
# 46|'Starfleet'  : PROPN NNP
# 47|'and'        : CCONJ CC
# 48|'the'        : DET   DT
# 49|'fifth'      : ADJ   JJ
# 50|'Federation' : PROPN NNP
# 51|'ship'       : NOUN  NN
# 52|'to'         : PART  TO
# 53|'bear'       : VERB  VB
# 54|'the'        : DET   DT
# 55|'name'       : NOUN  NN
# 56|'Enterprise' : NOUN  NN
# 57|'During'     : ADP   IN
# 58|'her'        : DET   PRP$
# 59|'career'     : NOUN  NN
# 60|'the'        : DET   DT
# 61|'Enterprise' : NOUN  NN
# 62|'served'     : VERB  VBD
# 63|'as'         : SCONJ IN
# 64|'the'        : DET   DT
# 65|'Federation' : PROPN NNP
# 66|'flagship'   : NOUN  NN
# 67|'The'        : DET   DT
# 68|'Enterprise' : PROPN NNP
# 69|'was'        : AUX   VBD
# 70|'destroyed'  : VERB  VBN
# 71|'during'     : ADP   IN
# 72|'the'        : DET   DT
# 73|'Battle'     : PROPN NNP
# 74|'of'         : ADP   IN
# 75|'Veridian'   : PROPN NNP
# 76|'III'        : NUM   CD
# 77|'in'         : ADP   IN
# 78|'2371'       : NUM   CD
# 79|'\n\n'       : SPACE _SP
# 80|'History'    : NOUN  NN
# 81|'\n'         : SPACE _SP
# 82|'Construction' : NOUN  NN
# 83|'and'        : CCONJ CC
# 84|'launch'     : VERB  VB
# 85|'\n'         : SPACE _SP
# 86|'The'        : DET   DT
# 87|'Enterprise' : PROPN NNP
# 88|'was'        : AUX   VBD
# 89|'built'      : VERB  VBN
# 90|'at'         : ADP   IN
# 91|'Utopia'     : PROPN NNP
# 92|'Planitia'   : PROPN NNP
# 93|'Fleet'      : PROPN NNP
# 94|'Yards'      : PROPN NNPS
# 95|'orbiting'   : VERB  VBG
# 96|'Mars'       : PROPN NNP
# 97|'in'         : ADP   IN
# 98|'the'        : DET   DT
# 99|'Solar'      : ADJ   JJ
# 100|'system'     : NOUN  NN
# 101|'The'        : DET   DT
# 102|'construction' : NOUN  NN
# 103|'was'        : AUX   VBD
# 104|'a'          : DET   DT
# 105|'massive'    : ADJ   JJ
# 106|'undertaking' : NOUN  NN
# 107|'involving'  : VERB  VBG
# 108|'thousands'  : NOUN  NNS
# 109|'of'         : ADP   IN
# 110|'people'     : NOUN  NNS
# 111|'across'     : ADP   IN
# 112|'disciplines' : NOUN  NNS
# 113|'Construction' : NOUN  NN
# 114|'was'        : AUX   VBD
# 115|'supervised' : VERB  VBN
# 116|'by'         : ADP   IN
# 117|'Commander'  : PROPN NNP
# 118|'Orfil'      : PROPN NNP
# 119|'Quinteros'  : PROPN NNP
# 120|'Dr'         : PROPN NNP
# 121|'Leah'       : PROPN NNP
# 122|'Brahms'     : PROPN NNP
# 123|'was'        : AUX   VBD
# 124|'responsible' : ADJ   JJ
# 125|'for'        : ADP   IN
# 126|'much'       : ADJ   JJ
# 127|'of'         : ADP   IN
# 128|'the'        : DET   DT
# 129|'Enterprises' : PROPN NNPS
# 130|'warp'       : ADJ   JJ
# 131|'propulsion' : NOUN  NN
# 132|'system'     : NOUN  NN
# 133|'design'     : NOUN  NN
# 134|'Some'       : DET   DT
# 135|'of'         : ADP   IN
# 136|'the'        : DET   DT
# 137|'Enterprises' : NOUN  NNS
# 138|'components' : NOUN  NNS
# 139|'were'       : AUX   VBD
# 140|'derived'    : VERB  VBN
# 141|'from'       : ADP   IN
# 142|'technology' : NOUN  NN
# 143|'originally' : ADV   RB
# 144|'developed'  : VERB  VBN
# 145|'on'         : ADP   IN
# 146|'the'        : DET   DT
# 147|'USS'        : PROPN NNP
# 148|'Pegasus'    : PROPN NNP
# 149|'\n\n'       : SPACE _SP
# 150|'One'        : NUM   CD
# 151|'of'         : ADP   IN
# 152|'the'        : DET   DT
# 153|'ships'      : NOUN  NNS
# 154|'nacelle'    : PROPN NNP
# 155|'tube'       : NOUN  NN
# 156|'was'        : AUX   VBD
# 157|'the'        : DET   DT
# 158|'site'       : NOUN  NN
# 159|'of'         : ADP   IN
# 160|'a'          : DET   DT
# 161|'multiple'   : ADJ   JJ
# 162|'murder'     : NOUN  NN
# 163|'-'          : PUNCT HYPH
# 164|'suicide'    : NOUN  NN
# 165|'while'      : SCONJ IN
# 166|'she'        : PRON  PRP
# 167|'was'        : AUX   VBD
# 168|'still'      : ADV   RB
# 169|'under'      : ADP   IN
# 170|'construction' : NOUN  NN
# 171|'at'         : ADP   IN
# 172|'Utopia'     : PROPN NNP
# 173|'Planitia'   : PROPN NNP
# 174|'A'          : PROPN NNP
# 175|'member'     : NOUN  NN
# 176|'of'         : ADP   IN
# 177|'the'        : DET   DT
# 178|'construction' : NOUN  NN
# 179|'team'       : NOUN  NN
# 180|'Walter'     : PROPN NNP
# 181|'Pierce'     : PROPN NNP
# 182|'became'     : VERB  VBD
# 183|'jealous'    : ADJ   JJ
# 184|'of'         : ADP   IN
# 185|'a'          : DET   DT
# 186|'former'     : ADJ   JJ
# 187|'lovers'     : NOUN  NNS
# 188|'new'        : ADJ   JJ
# 189|'relationship' : NOUN  NN
# 190|'He'         : PRON  PRP
# 191|'killed'     : VERB  VBD
# 192|'the'        : DET   DT
# 193|'two'        : NUM   CD
# 194|'officers'   : NOUN  NNS
# 195|'Marla'      : PROPN NNP
# 196|'Finn'       : PROPN NNP
# 197|'and'        : CCONJ CC
# 198|'William'    : PROPN NNP
# 199|'Hodges'     : PROPN NNP
# 200|'then'       : ADV   RB
# 201|'disposed'   : VERB  VBD
# 202|'of'         : ADP   IN
# 203|'their'      : DET   PRP$
# 204|'bodies'     : NOUN  NNS
# 205|'in'         : ADP   IN
# 206|'the'        : DET   DT
# 207|'plasma'     : NOUN  NN
# 208|'stream'     : NOUN  NN
# 209|'Pierce'     : PROPN NNP
# 210|'committed'  : VERB  VBD
# 211|'suicide'    : NOUN  NN
# 212|'in'         : ADP   IN
# 213|'the'        : DET   DT
# 214|'same'       : ADJ   JJ
# 215|'manner'     : NOUN  NN
# 216|'leaving'    : VERB  VBG
# 217|'a'          : DET   DT
# 218|'telepathic' : ADJ   JJ
# 219|'imprint'    : NOUN  NN
# 220|'in'         : ADP   IN
# 221|'a'          : DET   DT
# 222|'bulkhead'   : NOUN  NN
# 223|'that'       : DET   WDT
# 224|'was'        : AUX   VBD
# 225|'not'        : PART  RB
# 226|'discovered' : VERB  VBN
# 227|'until'      : ADP   IN
# 228|'2370'       : NUM   CD
# 229|'\n\n'       : SPACE _SP
# 230|'On'         : ADP   IN
# 231|'stardate'   : NOUN  NN
# 232|'407595'     : NUM   CD
# 233|'in'         : ADP   IN
# 234|'the'        : DET   DT
# 235|'year'       : NOUN  NN
# 236|'2363'       : NUM   CD
# 237|'the'        : DET   DT
# 238|'Enterprise' : PROPN NNP
# 239|'was'        : AUX   VBD
# 240|'launched'   : VERB  VBN
# 241|'from'       : ADP   IN
# 242|'Mars'       : PROPN NNP
# 243|'On'         : ADP   IN
# 244|'stardate'   : NOUN  NN
# 245|'410255'     : NUM   CD
# 246|'the'        : DET   DT
# 247|'Enterprise' : NOUN  NN
# 248|'was'        : AUX   VBD
# 249|'commissioned' : VERB  VBN
# 250|'\n\n'       : SPACE _SP
# 251|'These'      : DET   DT
# 252|'stardates'  : NOUN  NNS
# 253|'were'       : AUX   VBD
# 254|'nt'         : PART  RB
# 255|'mentioned'  : VERB  VBN
# 256|'in'         : ADP   IN
# 257|'dialog'     : NOUN  NN
# 258|'they'       : PRON  PRP
# 259|'were'       : AUX   VBD
# 260|'from'       : ADP   IN
# 261|'the'        : DET   DT
# 262|'Enterprise' : NOUN  NN
# 263|'dedication' : NOUN  NN
# 264|'plaque'     : NOUN  NN
# 265|'\n\n'       : SPACE _SP
# 266|'Final'      : ADJ   JJ
# 267|'systems'    : NOUN  NNS
# 268|'completion' : NOUN  NN
# 269|'and'        : CCONJ CC
# 270|'shakedown'  : NOUN  NN
# 271|'was'        : AUX   VBD
# 272|'conducted'  : VERB  VBN
# 273|'at'         : ADP   IN
# 274|'Earth'      : PROPN NNP
# 275|'Station'    : PROPN NNP
# 276|'McKinley'   : PROPN NNP
# 277|'Captain'    : PROPN NNP
# 278|'Jean'       : PROPN NNP
# 279|'-'          : PUNCT HYPH
# 280|'Luc'        : PROPN NNP
# 281|'Picard'     : PROPN NNP
# 282|'took'       : VERB  VBD
# 283|'command'    : NOUN  NN
# 284|'of'         : ADP   IN
# 285|'the'        : DET   DT
# 286|'ship'       : NOUN  NN
# 287|'on'         : ADP   IN
# 288|'stardate'   : NOUN  NN
# 289|'41148'      : NUM   CD
# 290|'at'         : ADP   IN
# 291|'the'        : DET   DT
# 292|'order'      : NOUN  NN
# 293|'of'         : ADP   IN
# 294|'Rear'       : PROPN NNP
# 295|'Admiral'    : PROPN NNP
# 296|'Norah'      : PROPN NNP
# 297|'Satie'      : PROPN NNP
# 298|'\n\n'       : SPACE _SP
# 299|'Legacy'     : NOUN  NN
# 300|'\n'         : SPACE _SP
# 301|'Commander'  : PROPN NNP
# 302|'Riker'      : PROPN NNP
# 303|'was'        : AUX   VBD
# 304|'upset'      : ADJ   JJ
# 305|'over'       : ADP   IN
# 306|'the'        : DET   DT
# 307|'loss'       : NOUN  NN
# 308|'of'         : ADP   IN
# 309|'the'        : DET   DT
# 310|'Enterprise' : NOUN  NN
# 311|'Having'     : VERB  VBG
# 312|'hoped'      : VERB  VBN
# 313|'he'         : PRON  PRP
# 314|'would'      : VERB  MD
# 315|'one'        : NUM   CD
# 316|'day'        : NOUN  NN
# 317|'command'    : VERB  VB
# 318|'the'        : DET   DT
# 319|'ship'       : NOUN  NN
# 320|'he'         : PRON  PRP
# 321|'was'        : AUX   VBD
# 322|'disappointed' : VERB  VBN
# 323|'that'       : SCONJ IN
# 324|'he'         : PRON  PRP
# 325|'never'      : ADV   RB
# 326|'got'        : VERB  VBD
# 327|'that'       : DET   DT
# 328|'opportunity' : NOUN  NN
# 329|'However'    : ADV   RB
# 330|'Picard'     : PROPN NNP
# 331|'expressed'  : VERB  VBD
# 332|'doubt'      : NOUN  NN
# 333|'that'       : SCONJ IN
# 334|'the'        : DET   DT
# 335|'Enterprise' : PROPN NNP
# 336|'-'          : PUNCT HYPH
# 337|'D'          : PROPN NNP
# 338|'would'      : VERB  MD
# 339|'be'         : AUX   VB
# 340|'the'        : DET   DT
# 341|'last'       : ADJ   JJ
# 342|'vessel'     : NOUN  NN
# 343|'to'         : PART  TO
# 344|'carry'      : VERB  VB
# 345|'the'        : DET   DT
# 346|'name'       : NOUN  NN
# 347|'\n\n'       : SPACE _SP
# 348|'The'        : DET   DT
# 349|'Enterprise' : PROPN NNP
# 350|'was'        : AUX   VBD
# 351|'so'         : ADV   RB
# 352|'dear'       : ADJ   JJ
# 353|'to'         : ADP   IN
# 354|'Worf'       : VERB  VB
# 355|'that'       : SCONJ IN
# 356|'shortly'    : ADV   RB
# 357|'after'      : ADP   IN
# 358|'being'      : AUX   VBG
# 359|'reassigned' : VERB  VBN
# 360|'to'         : ADP   IN
# 361|'Deep'       : PROPN NNP
# 362|'Space'      : PROPN NNP
# 363|'9'          : NUM   CD
# 364|'in'         : ADP   IN
# 365|'2372'       : NUM   CD
# 366|'he'         : PRON  PRP
# 367|'briefly'    : ADV   RB
# 368|'considered' : VERB  VBD
# 369|'resigning'  : VERB  VBG
# 370|'from'       : ADP   IN
# 371|'Starfleet'  : PROPN NNP
# 372|'Station'    : PROPN NNP
# 373|'commander'  : NOUN  NN
# 374|'Captain'    : PROPN NNP
# 375|'Benjamin'   : PROPN NNP
# 376|'Sisko'      : PROPN NNP
# 377|'expressed'  : VERB  VBD
# 378|'regret'     : NOUN  NN
# 379|'on'         : ADP   IN
# 380|'the'        : DET   DT
# 381|'loss'       : NOUN  NN
# 382|'of'         : ADP   IN
# 383|'the'        : DET   DT
# 384|'Enterprise' : NOUN  NN
# 385|'and'        : CCONJ CC
# 386|'offered'    : VERB  VBD
# 387|'his'        : DET   PRP$
# 388|'condolences' : NOUN  NNS
# 389|'over'       : ADP   IN
# 390|'the'        : DET   DT
# 391|'destruction' : NOUN  NN
# 392|'of'         : ADP   IN
# 393|'the'        : DET   DT
# 394|'ship'       : NOUN  NN
# 395|'to'         : ADP   IN
# 396|'Worf'       : PROPN NNP
# 397|'saying'     : VERB  VBG
# 398|'the'        : DET   DT
# 399|'Enterprise' : NOUN  NN
# 400|'was'        : AUX   VBD
# 401|'a'          : DET   DT
# 402|'good'       : ADJ   JJ
# 403|'ship'       : NOUN  NN
# 404|'\n\n'       : SPACE _SP
# 405|'Captain'    : PROPN NNP
# 406|'Picards'    : PROPN NNP
# 407|'belief'     : NOUN  NN
# 408|'that'       : SCONJ IN
# 409|'the'        : DET   DT
# 410|'Enterprise' : PROPN NNP
# 411|'-'          : PUNCT HYPH
# 412|'D'          : PROPN NNP
# 413|'would'      : VERB  MD
# 414|'not'        : PART  RB
# 415|'be'         : AUX   VB
# 416|'the'        : DET   DT
# 417|'final'      : ADJ   JJ
# 418|'ship'       : NOUN  NN
# 419|'to'         : PART  TO
# 420|'bear'       : VERB  VB
# 421|'the'        : DET   DT
# 422|'name'       : NOUN  NN
# 423|'was'        : AUX   VBD
# 424|'borne'      : VERB  VBN
# 425|'out'        : ADP   RP
# 426|'with'       : ADP   IN
# 427|'the'        : DET   DT
# 428|'christening' : NOUN  NN
# 429|'of'         : ADP   IN
# 430|'the'        : DET   DT
# 431|'Class'      : PROPN NNP
# 432|'Sovereign'  : PROPN NNP
# 433|'USS'        : PROPN NNP
# 434|'Enterprise' : PROPN NNP
# 435|'NCC-1701-E' : PROPN NNP
# 436|'later'      : ADV   RB
# 437|'the'        : DET   DT
# 438|'same'       : ADJ   JJ
# 439|'year'       : NOUN  NN
# 440|'In'         : ADP   IN
# 441|'that'       : DET   DT
# 442|'instance'   : NOUN  NN
# 443|'the'        : DET   DT
# 444|'legacy'     : NOUN  NN
# 445|'of'         : ADP   IN
# 446|'the'        : DET   DT
# 447|'Enterprise' : NOUN  NN
# 448|'continued'  : VERB  VBD
# 449|'with'       : ADP   IN
# 450|'Picard'     : NOUN  NN
# 451|'reprising'  : VERB  VBG
# 452|'his'        : DET   PRP$
# 453|'role'       : NOUN  NN
# 454|'as'         : SCONJ IN
# 455|'CO'         : PROPN NNP
# 456|'and'        : CCONJ CC
# 457|'selecting'  : VERB  VBG
# 458|'most'       : ADJ   JJS
# 459|'of'         : ADP   IN
# 460|'the'        : DET   DT
# 461|'former'     : ADJ   JJ
# 462|'crew'       : NOUN  NN
# 463|'from'       : ADP   IN
# 464|'the'        : DET   DT
# 465|'Enterprise' : PROPN NNP
# 466|'-'          : PUNCT HYPH
# 467|'D'          : NOUN  NN
# 468|'with'       : ADP   IN
# 469|'the'        : DET   DT
# 470|'notable'    : ADJ   JJ
# 471|'exception'  : NOUN  NN
# 472|'of'         : ADP   IN
# 473|'Worf'       : PROPN NNP
# 474|'due'        : ADP   IN
# 475|'to'         : ADP   IN
# 476|'his'        : DET   PRP$
# 477|'most'       : ADV   RBS
# 478|'recent'     : ADJ   JJ
# 479|'assignment' : NOUN  NN
# 480|'to'         : ADP   IN
# 481|'DS9'        : PROPN NNP
# 482|'though'     : SCONJ IN
# 483|'he'         : PRON  PRP
# 484|'temporarily' : ADV   RB
# 485|'joined'     : VERB  VBD
# 486|'the'        : DET   DT
# 487|'Enterprise' : NOUN  NN
# 488|'-'          : PUNCT HYPH
# 489|'E'          : NOUN  NN
# 490|'crew'       : NOUN  NN
# 491|'on'         : ADP   IN
# 492|'several'    : ADJ   JJ
# 493|'of'         : ADP   IN
# 494|'their'      : DET   PRP$
# 495|'more'       : ADJ   JJR
# 496|'notable'    : ADJ   JJ
# 497|'missions'   : NOUN  NNS

# %% [markdown]
# ### Lemmatisation

# %%
## spaCy
print('i | Token        Lemma')
print('--| ------------ ------------')
for i, t in enumerate(nlp_text):
    print('%2d| %-12r %r' % (i+1, t.text, t.lemma_))
    if t.text == '.':
        break
# Out:
# i | Token        Lemma
# --| ------------ ------------
#  1| 'USS'        'USS'
#  2| 'Enterprise' 'Enterprise'
#  3| 'NCC-1701-D' 'NCC-1701-D'
#  4| '\n\n'       '\n\n'
#  5| 'For'        'for'
#  6| 'five'       'five'
#  7| 'hundred'    'hundred'
#  8| 'years'      'year'
#  9| 'every'      'every'
# 10| 'ship'       'ship'
# 11| 'that'       'that'
# 12| 'has'        'have'
# 13| 'borne'      'bear'
# 14| 'the'        'the'
# 15| 'name'       'name'
# 16| 'of'         'of'
# 17| 'the'        'the'
# 18| 'Enterprise' 'enterprise'
# 19| 'has'        'have'
# 20| 'become'     'become'
# 21| 'a'          'a'
# 22| 'legend'     'legend'
# 23| 'This'       'this'
# 24| 'one'        'one'
# 25| 'is'         'be'
# 26| 'no'         'no'
# 27| 'different'  'different'
# 28| '\n\n'       '\n\n'
# 29| 'The'        'the'
# 30| 'USS'        'USS'
# 31| 'Enterprise' 'Enterprise'
# 32| 'NCC-1701-D' 'NCC-1701-D'
# 33| 'was'        'be'
# 34| 'a'          'a'
# 35| '24th'       '24th'
# 36| 'century'    'century'
# 37| 'United'     'United'
# 38| 'Federation' 'Federation'
# 39| 'of'         'of'
# 40| 'Planets'    'Planets'
# 41| 'Galaxy'     'Galaxy'
# 42| 'Class'      'Class'
# 43| 'starship'   'starship'
# 44| 'operated'   'operate'
# 45| 'by'         'by'
# 46| 'Starfleet'  'Starfleet'
# 47| 'and'        'and'
# 48| 'the'        'the'
# 49| 'fifth'      'fifth'
# 50| 'Federation' 'Federation'
# 51| 'ship'       'ship'
# 52| 'to'         'to'
# 53| 'bear'       'bear'
# 54| 'the'        'the'
# 55| 'name'       'name'
# 56| 'Enterprise' 'enterprise'
# 57| 'During'     'during'
# 58| 'her'        '-PRON-'
# 59| 'career'     'career'
# 60| 'the'        'the'
# 61| 'Enterprise' 'enterprise'
# 62| 'served'     'serve'
# 63| 'as'         'as'
# 64| 'the'        'the'
# 65| 'Federation' 'Federation'
# 66| 'flagship'   'flagship'
# 67| 'The'        'the'
# 68| 'Enterprise' 'Enterprise'
# 69| 'was'        'be'
# 70| 'destroyed'  'destroy'
# 71| 'during'     'during'
# 72| 'the'        'the'
# 73| 'Battle'     'Battle'
# 74| 'of'         'of'
# 75| 'Veridian'   'Veridian'
# 76| 'III'        'iii'
# 77| 'in'         'in'
# 78| '2371'       '2371'
# 79| '\n\n'       '\n\n'
# 80| 'History'    'history'
# 81| '\n'         '\n'
# 82| 'Construction' 'construction'
# 83| 'and'        'and'
# 84| 'launch'     'launch'
# 85| '\n'         '\n'
# 86| 'The'        'the'
# 87| 'Enterprise' 'Enterprise'
# 88| 'was'        'be'
# 89| 'built'      'build'
# 90| 'at'         'at'
# 91| 'Utopia'     'Utopia'
# 92| 'Planitia'   'Planitia'
# 93| 'Fleet'      'Fleet'
# 94| 'Yards'      'Yards'
# 95| 'orbiting'   'orbit'
# 96| 'Mars'       'Mars'
# 97| 'in'         'in'
# 98| 'the'        'the'
# 99| 'Solar'      'solar'
# 100| 'system'     'system'
# 101| 'The'        'the'
# 102| 'construction' 'construction'
# 103| 'was'        'be'
# 104| 'a'          'a'
# 105| 'massive'    'massive'
# 106| 'undertaking' 'undertaking'
# 107| 'involving'  'involve'
# 108| 'thousands'  'thousand'
# 109| 'of'         'of'
# 110| 'people'     'people'
# 111| 'across'     'across'
# 112| 'disciplines' 'discipline'
# 113| 'Construction' 'construction'
# 114| 'was'        'be'
# 115| 'supervised' 'supervise'
# 116| 'by'         'by'
# 117| 'Commander'  'Commander'
# 118| 'Orfil'      'Orfil'
# 119| 'Quinteros'  'Quinteros'
# 120| 'Dr'         'Dr'
# 121| 'Leah'       'Leah'
# 122| 'Brahms'     'Brahms'
# 123| 'was'        'be'
# 124| 'responsible' 'responsible'
# 125| 'for'        'for'
# 126| 'much'       'much'
# 127| 'of'         'of'
# 128| 'the'        'the'
# 129| 'Enterprises' 'Enterprises'
# 130| 'warp'       'warp'
# 131| 'propulsion' 'propulsion'
# 132| 'system'     'system'
# 133| 'design'     'design'
# 134| 'Some'       'some'
# 135| 'of'         'of'
# 136| 'the'        'the'
# 137| 'Enterprises' 'enterprise'
# 138| 'components' 'component'
# 139| 'were'       'be'
# 140| 'derived'    'derive'
# 141| 'from'       'from'
# 142| 'technology' 'technology'
# 143| 'originally' 'originally'
# 144| 'developed'  'develop'
# 145| 'on'         'on'
# 146| 'the'        'the'
# 147| 'USS'        'USS'
# 148| 'Pegasus'    'Pegasus'
# 149| '\n\n'       '\n\n'
# 150| 'One'        'one'
# 151| 'of'         'of'
# 152| 'the'        'the'
# 153| 'ships'      'ship'
# 154| 'nacelle'    'nacelle'
# 155| 'tube'       'tube'
# 156| 'was'        'be'
# 157| 'the'        'the'
# 158| 'site'       'site'
# 159| 'of'         'of'
# 160| 'a'          'a'
# 161| 'multiple'   'multiple'
# 162| 'murder'     'murder'
# 163| '-'          '-'
# 164| 'suicide'    'suicide'
# 165| 'while'      'while'
# 166| 'she'        '-PRON-'
# 167| 'was'        'be'
# 168| 'still'      'still'
# 169| 'under'      'under'
# 170| 'construction' 'construction'
# 171| 'at'         'at'
# 172| 'Utopia'     'Utopia'
# 173| 'Planitia'   'Planitia'
# 174| 'A'          'A'
# 175| 'member'     'member'
# 176| 'of'         'of'
# 177| 'the'        'the'
# 178| 'construction' 'construction'
# 179| 'team'       'team'
# 180| 'Walter'     'Walter'
# 181| 'Pierce'     'Pierce'
# 182| 'became'     'become'
# 183| 'jealous'    'jealous'
# 184| 'of'         'of'
# 185| 'a'          'a'
# 186| 'former'     'former'
# 187| 'lovers'     'lover'
# 188| 'new'        'new'
# 189| 'relationship' 'relationship'
# 190| 'He'         '-PRON-'
# 191| 'killed'     'kill'
# 192| 'the'        'the'
# 193| 'two'        'two'
# 194| 'officers'   'officer'
# 195| 'Marla'      'Marla'
# 196| 'Finn'       'Finn'
# 197| 'and'        'and'
# 198| 'William'    'William'
# 199| 'Hodges'     'Hodges'
# 200| 'then'       'then'
# 201| 'disposed'   'dispose'
# 202| 'of'         'of'
# 203| 'their'      '-PRON-'
# 204| 'bodies'     'body'
# 205| 'in'         'in'
# 206| 'the'        'the'
# 207| 'plasma'     'plasma'
# 208| 'stream'     'stream'
# 209| 'Pierce'     'Pierce'
# 210| 'committed'  'commit'
# 211| 'suicide'    'suicide'
# 212| 'in'         'in'
# 213| 'the'        'the'
# 214| 'same'       'same'
# 215| 'manner'     'manner'
# 216| 'leaving'    'leave'
# 217| 'a'          'a'
# 218| 'telepathic' 'telepathic'
# 219| 'imprint'    'imprint'
# 220| 'in'         'in'
# 221| 'a'          'a'
# 222| 'bulkhead'   'bulkhead'
# 223| 'that'       'that'
# 224| 'was'        'be'
# 225| 'not'        'not'
# 226| 'discovered' 'discover'
# 227| 'until'      'until'
# 228| '2370'       '2370'
# 229| '\n\n'       '\n\n'
# 230| 'On'         'on'
# 231| 'stardate'   'stardate'
# 232| '407595'     '407595'
# 233| 'in'         'in'
# 234| 'the'        'the'
# 235| 'year'       'year'
# 236| '2363'       '2363'
# 237| 'the'        'the'
# 238| 'Enterprise' 'Enterprise'
# 239| 'was'        'be'
# 240| 'launched'   'launch'
# 241| 'from'       'from'
# 242| 'Mars'       'Mars'
# 243| 'On'         'on'
# 244| 'stardate'   'stardate'
# 245| '410255'     '410255'
# 246| 'the'        'the'
# 247| 'Enterprise' 'enterprise'
# 248| 'was'        'be'
# 249| 'commissioned' 'commission'
# 250| '\n\n'       '\n\n'
# 251| 'These'      'these'
# 252| 'stardates'  'stardate'
# 253| 'were'       'be'
# 254| 'nt'         'not'
# 255| 'mentioned'  'mention'
# 256| 'in'         'in'
# 257| 'dialog'     'dialog'
# 258| 'they'       '-PRON-'
# 259| 'were'       'be'
# 260| 'from'       'from'
# 261| 'the'        'the'
# 262| 'Enterprise' 'enterprise'
# 263| 'dedication' 'dedication'
# 264| 'plaque'     'plaque'
# 265| '\n\n'       '\n\n'
# 266| 'Final'      'final'
# 267| 'systems'    'system'
# 268| 'completion' 'completion'
# 269| 'and'        'and'
# 270| 'shakedown'  'shakedown'
# 271| 'was'        'be'
# 272| 'conducted'  'conduct'
# 273| 'at'         'at'
# 274| 'Earth'      'Earth'
# 275| 'Station'    'Station'
# 276| 'McKinley'   'McKinley'
# 277| 'Captain'    'Captain'
# 278| 'Jean'       'Jean'
# 279| '-'          '-'
# 280| 'Luc'        'Luc'
# 281| 'Picard'     'Picard'
# 282| 'took'       'take'
# 283| 'command'    'command'
# 284| 'of'         'of'
# 285| 'the'        'the'
# 286| 'ship'       'ship'
# 287| 'on'         'on'
# 288| 'stardate'   'stardate'
# 289| '41148'      '41148'
# 290| 'at'         'at'
# 291| 'the'        'the'
# 292| 'order'      'order'
# 293| 'of'         'of'
# 294| 'Rear'       'Rear'
# 295| 'Admiral'    'Admiral'
# 296| 'Norah'      'Norah'
# 297| 'Satie'      'Satie'
# 298| '\n\n'       '\n\n'
# 299| 'Legacy'     'legacy'
# 300| '\n'         '\n'
# 301| 'Commander'  'Commander'
# 302| 'Riker'      'Riker'
# 303| 'was'        'be'
# 304| 'upset'      'upset'
# 305| 'over'       'over'
# 306| 'the'        'the'
# 307| 'loss'       'loss'
# 308| 'of'         'of'
# 309| 'the'        'the'
# 310| 'Enterprise' 'enterprise'
# 311| 'Having'     'have'
# 312| 'hoped'      'hope'
# 313| 'he'         '-PRON-'
# 314| 'would'      'would'
# 315| 'one'        'one'
# 316| 'day'        'day'
# 317| 'command'    'command'
# 318| 'the'        'the'
# 319| 'ship'       'ship'
# 320| 'he'         '-PRON-'
# 321| 'was'        'be'
# 322| 'disappointed' 'disappoint'
# 323| 'that'       'that'
# 324| 'he'         '-PRON-'
# 325| 'never'      'never'
# 326| 'got'        'get'
# 327| 'that'       'that'
# 328| 'opportunity' 'opportunity'
# 329| 'However'    'however'
# 330| 'Picard'     'Picard'
# 331| 'expressed'  'express'
# 332| 'doubt'      'doubt'
# 333| 'that'       'that'
# 334| 'the'        'the'
# 335| 'Enterprise' 'Enterprise'
# 336| '-'          '-'
# 337| 'D'          'D'
# 338| 'would'      'would'
# 339| 'be'         'be'
# 340| 'the'        'the'
# 341| 'last'       'last'
# 342| 'vessel'     'vessel'
# 343| 'to'         'to'
# 344| 'carry'      'carry'
# 345| 'the'        'the'
# 346| 'name'       'name'
# 347| '\n\n'       '\n\n'
# 348| 'The'        'the'
# 349| 'Enterprise' 'Enterprise'
# 350| 'was'        'be'
# 351| 'so'         'so'
# 352| 'dear'       'dear'
# 353| 'to'         'to'
# 354| 'Worf'       'worf'
# 355| 'that'       'that'
# 356| 'shortly'    'shortly'
# 357| 'after'      'after'
# 358| 'being'      'be'
# 359| 'reassigned' 'reassign'
# 360| 'to'         'to'
# 361| 'Deep'       'Deep'
# 362| 'Space'      'Space'
# 363| '9'          '9'
# 364| 'in'         'in'
# 365| '2372'       '2372'
# 366| 'he'         '-PRON-'
# 367| 'briefly'    'briefly'
# 368| 'considered' 'consider'
# 369| 'resigning'  'resign'
# 370| 'from'       'from'
# 371| 'Starfleet'  'Starfleet'
# 372| 'Station'    'Station'
# 373| 'commander'  'commander'
# 374| 'Captain'    'Captain'
# 375| 'Benjamin'   'Benjamin'
# 376| 'Sisko'      'Sisko'
# 377| 'expressed'  'express'
# 378| 'regret'     'regret'
# 379| 'on'         'on'
# 380| 'the'        'the'
# 381| 'loss'       'loss'
# 382| 'of'         'of'
# 383| 'the'        'the'
# 384| 'Enterprise' 'enterprise'
# 385| 'and'        'and'
# 386| 'offered'    'offer'
# 387| 'his'        '-PRON-'
# 388| 'condolences' 'condolence'
# 389| 'over'       'over'
# 390| 'the'        'the'
# 391| 'destruction' 'destruction'
# 392| 'of'         'of'
# 393| 'the'        'the'
# 394| 'ship'       'ship'
# 395| 'to'         'to'
# 396| 'Worf'       'Worf'
# 397| 'saying'     'say'
# 398| 'the'        'the'
# 399| 'Enterprise' 'enterprise'
# 400| 'was'        'be'
# 401| 'a'          'a'
# 402| 'good'       'good'
# 403| 'ship'       'ship'
# 404| '\n\n'       '\n\n'
# 405| 'Captain'    'Captain'
# 406| 'Picards'    'Picards'
# 407| 'belief'     'belief'
# 408| 'that'       'that'
# 409| 'the'        'the'
# 410| 'Enterprise' 'Enterprise'
# 411| '-'          '-'
# 412| 'D'          'D'
# 413| 'would'      'would'
# 414| 'not'        'not'
# 415| 'be'         'be'
# 416| 'the'        'the'
# 417| 'final'      'final'
# 418| 'ship'       'ship'
# 419| 'to'         'to'
# 420| 'bear'       'bear'
# 421| 'the'        'the'
# 422| 'name'       'name'
# 423| 'was'        'be'
# 424| 'borne'      'bear'
# 425| 'out'        'out'
# 426| 'with'       'with'
# 427| 'the'        'the'
# 428| 'christening' 'christening'
# 429| 'of'         'of'
# 430| 'the'        'the'
# 431| 'Class'      'Class'
# 432| 'Sovereign'  'Sovereign'
# 433| 'USS'        'USS'
# 434| 'Enterprise' 'Enterprise'
# 435| 'NCC-1701-E' 'NCC-1701-E'
# 436| 'later'      'later'
# 437| 'the'        'the'
# 438| 'same'       'same'
# 439| 'year'       'year'
# 440| 'In'         'in'
# 441| 'that'       'that'
# 442| 'instance'   'instance'
# 443| 'the'        'the'
# 444| 'legacy'     'legacy'
# 445| 'of'         'of'
# 446| 'the'        'the'
# 447| 'Enterprise' 'enterprise'
# 448| 'continued'  'continue'
# 449| 'with'       'with'
# 450| 'Picard'     'picard'
# 451| 'reprising'  'reprise'
# 452| 'his'        '-PRON-'
# 453| 'role'       'role'
# 454| 'as'         'as'
# 455| 'CO'         'CO'
# 456| 'and'        'and'
# 457| 'selecting'  'select'
# 458| 'most'       'most'
# 459| 'of'         'of'
# 460| 'the'        'the'
# 461| 'former'     'former'
# 462| 'crew'       'crew'
# 463| 'from'       'from'
# 464| 'the'        'the'
# 465| 'Enterprise' 'Enterprise'
# 466| '-'          '-'
# 467| 'D'          'd'
# 468| 'with'       'with'
# 469| 'the'        'the'
# 470| 'notable'    'notable'
# 471| 'exception'  'exception'
# 472| 'of'         'of'
# 473| 'Worf'       'Worf'
# 474| 'due'        'due'
# 475| 'to'         'to'
# 476| 'his'        '-PRON-'
# 477| 'most'       'most'
# 478| 'recent'     'recent'
# 479| 'assignment' 'assignment'
# 480| 'to'         'to'
# 481| 'DS9'        'DS9'
# 482| 'though'     'though'
# 483| 'he'         '-PRON-'
# 484| 'temporarily' 'temporarily'
# 485| 'joined'     'join'
# 486| 'the'        'the'
# 487| 'Enterprise' 'enterprise'
# 488| '-'          '-'
# 489| 'E'          'e'
# 490| 'crew'       'crew'
# 491| 'on'         'on'
# 492| 'several'    'several'
# 493| 'of'         'of'
# 494| 'their'      '-PRON-'
# 495| 'more'       'more'
# 496| 'notable'    'notable'
# 497| 'missions'   'mission'

# %%
plot_words(['%r' % t.lemma_ for t in nlp_text if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Entity Recognition

# %%
## spaCy
for i, s in enumerate(nlp_text.sents):
    print('%2d: %s' % (i, re.sub(r'\n+', '', s.text)))
    if s.as_doc().ents:
        print('-'*80)
        for e in s.as_doc().ents:
            print('%-11s: %s' % (e.label_, re.sub(r'\n+', '', e.text)))
    print('='*80)
# Out:
#  0: USS Enterprise NCC-1701-D
# --------------------------------------------------------------------------------
# ORG        : USS Enterprise NCC-1701-D
# ================================================================================
#  1: For five hundred years every ship that has borne the name of the Enterprise has become a legend
# --------------------------------------------------------------------------------
# DATE       : five hundred years
# ================================================================================
#  2: This one is no different
# ================================================================================
#  3: The USS Enterprise NCC-1701-D was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet and the fifth Federation ship to bear the name Enterprise During her career the Enterprise served as the Federation flagship
# --------------------------------------------------------------------------------
# PRODUCT    : The USS Enterprise NCC-1701-D
# DATE       : a 24th century
# ORG        : United Federation of Planets Galaxy Class
# ORDINAL    : fifth
# ORG        : Federation
# ================================================================================
#  4: The Enterprise was destroyed during the Battle of Veridian III in 2371HistoryConstruction and launch
# --------------------------------------------------------------------------------
# EVENT      : the Battle of Veridian III
# DATE       : 2371
# ================================================================================
#  5: The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system
# --------------------------------------------------------------------------------
# ORG        : Utopia Planitia Fleet Yards
# LOC        : Mars
# LOC        : Solar
# ================================================================================
#  6: The construction was a massive undertaking involving thousands of people across disciplines Construction was supervised by
# --------------------------------------------------------------------------------
# CARDINAL   : thousands
# ================================================================================
#  7: Commander Orfil Quinteros
# --------------------------------------------------------------------------------
# PERSON     : Orfil Quinteros
# ================================================================================
#  8: Dr Leah Brahms was responsible for much of the Enterprises warp propulsion system design
# --------------------------------------------------------------------------------
# PERSON     : Leah Brahms
# ================================================================================
#  9: Some of the Enterprises components were derived from technology originally developed on the USS Pegasus
# --------------------------------------------------------------------------------
# PRODUCT    : the USS Pegasus
# ================================================================================
# 10: One of the ships
# --------------------------------------------------------------------------------
# CARDINAL   : One
# ================================================================================
# 11: nacelle tube was the site of a multiple murder-suicide while she was still under construction at Utopia Planitia
# --------------------------------------------------------------------------------
# ORG        : Utopia Planitia
# ================================================================================
# 12: A member of the construction team Walter Pierce became jealous of a former lovers new relationship He killed the two officers Marla Finn and William Hodges
# --------------------------------------------------------------------------------
# PERSON     : Walter Pierce
# CARDINAL   : two
# PERSON     : Marla Finn
# PERSON     : William Hodges
# ================================================================================
# 13: then disposed of their bodies in the plasma stream
# ================================================================================
# 14: Pierce committed suicide in the same manner leaving a telepathic imprint in a bulkhead that was not discovered until 2370
# --------------------------------------------------------------------------------
# DATE       : 2370
# ================================================================================
# 15: On stardate 407595 in the year 2363 the Enterprise was launched from Mars On stardate 410255
# --------------------------------------------------------------------------------
# CARDINAL   : 407595
# DATE       : the year 2363
# LOC        : Mars
# CARDINAL   : 410255
# ================================================================================
# 16: the Enterprise was commissioned
# ================================================================================
# 17: These stardates werent mentioned in dialog
# ================================================================================
# 18: they were from the Enterprise dedication plaque
# ================================================================================
# 19: Final systems completion and shakedown was conducted at
# ================================================================================
# 20: Earth Station McKinley Captain Jean-Luc Picard took command of the ship on stardate 41148 at the order of Rear Admiral Norah SatieLegacy
# --------------------------------------------------------------------------------
# FAC        : Earth Station McKinley
# PERSON     : Jean-Luc Picard
# DATE       : 41148
# ================================================================================
# 21: Commander Riker was upset over the loss of the Enterprise Having hoped he would one day command the ship he was disappointed that he never got that opportunity
# --------------------------------------------------------------------------------
# PERSON     : Riker
# ORG        : the Enterprise Having
# DATE       : one day
# ================================================================================
# 22: However Picard expressed doubt that the Enterprise-D would be the last vessel to carry the name
# --------------------------------------------------------------------------------
# PERSON     : Picard
# ================================================================================
# 23: The Enterprise was so dear to Worf that shortly after being reassigned to Deep Space 9 in 2372 he briefly considered resigning from Starfleet Station commander Captain Benjamin Sisko expressed regret on the loss of the Enterprise and offered his condolences over the destruction of the ship to Worf saying the Enterprise was a good ship
# --------------------------------------------------------------------------------
# FAC        : Deep Space 9
# DATE       : 2372
# ORG        : Starfleet Station
# PERSON     : Captain Benjamin Sisko
# ================================================================================
# 24: Captain Picards belief that the Enterprise-D would not be the final ship to bear the name was borne out with the christening of the Class Sovereign USS Enterprise NCC-1701-E later the same year
# --------------------------------------------------------------------------------
# ORG        : the Class Sovereign USS Enterprise NCC-1701-E
# DATE       : later the same year
# ================================================================================
# 25: In that instance the legacy of the Enterprise continued with Picard reprising his role as CO and selecting most of the former crew from the Enterprise-D with the notable exception of Worf due to his most recent assignment to DS9 though he temporarily joined the Enterprise-E crew on several of their more notable missions
# --------------------------------------------------------------------------------
# PERSON     : Picard
# ORG        : Worf
# ================================================================================

# %% [markdown]
# ## Extra: Using NLTK for NLP
#
# ### Tokenise

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# use nltk to find tokens
tokens = nltk.word_tokenize(text)

for i, t in enumerate(tokens[:25]):
    print('%2d| %r' % (i+1, t))
# Out:
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701-D'
#  5| ')'
#  6| "''"
#  7| 'For'
#  8| 'five'
#  9| 'hundred'
# 10| 'years'
# 11| ','
# 12| 'every'
# 13| 'ship'
# 14| 'that'
# 15| 'has'
# 16| 'borne'
# 17| 'the'
# 18| 'name'
# 19| 'of'
# 20| 'the'
# 21| 'Enterprise'
# 22| 'has'
# 23| 'become'
# 24| 'a'
# 25| 'legend'

# %%
plot_words(tokens)

# %% [markdown]
# ### Stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopWords = nltk.corpus.stopwords.words('english')

stopWords.sort()
print(', '.join(stopWords))
# Out:
# a, about, above, after, again, against, ain, all, am, an, and, any, are, aren, aren't, as, at, be, because, been, before, being, below, between, both, but, by, can, couldn, couldn't, d, did, didn, didn't, do, does, doesn, doesn't, doing, don, don't, down, during, each, few, for, from, further, had, hadn, hadn't, has, hasn, hasn't, have, haven, haven't, having, he, her, here, hers, herself, him, himself, his, how, i, if, in, into, is, isn, isn't, it, it's, its, itself, just, ll, m, ma, me, mightn, mightn't, more, most, mustn, mustn't, my, myself, needn, needn't, no, nor, not, now, o, of, off, on, once, only, or, other, our, ours, ourselves, out, over, own, re, s, same, shan, shan't, she, she's, should, should've, shouldn, shouldn't, so, some, such, t, than, that, that'll, the, their, theirs, them, themselves, then, there, these, they, this, those, through, to, too, under, until, up, ve, very, was, wasn, wasn't, we, were, weren, weren't, what, when, where, which, while, who, whom, why, will, with, won, won't, wouldn, wouldn't, y, you, you'd, you'll, you're, you've, your, yours, yourself, yourselves

# %%
# ANSWER
# NOTE: see the `.lower()` method applied to token
tokens_no_stop = [new_token.lower() for new_token in tokens if new_token.lower() not in stopWords]  # create a list of tokens withOUT the stop words

# %%
## NLTK
i = 0
j = 0

print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
while i < len(tokens):
    # same word
    if tokens[i] == tokens_no_stop[j]:
        print('%2d| %-15r %r' % (i+1, tokens[i], tokens_no_stop[j]))
        j += 1
    # not the same word
    else:
        print('%2d| %-15r' % (i+1, tokens[i]))

    # next word
    i += 1
    # break after the first sentence
    if tokens[i-1] == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701-D'
#  5| ')'
#  6| "''"
#  7| 'For'
#  8| 'five'
#  9| 'hundred'
# 10| 'years'
# 11| ','
# 12| 'every'
# 13| 'ship'
# 14| 'that'
# 15| 'has'
# 16| 'borne'
# 17| 'the'
# 18| 'name'
# 19| 'of'
# 20| 'the'
# 21| 'Enterprise'
# 22| 'has'
# 23| 'become'
# 24| 'a'
# 25| 'legend'
# 26| '.'

# %%
# Create plot of words without stopword
# ANSWER

# %% [markdown]
# ### Check Part of Speech

# %%
# define PoS
pos_list = {
    'CC':   'coordinating conjunction',
    'CD':   'cardinal digit',
    'DT':   'determiner',
    'EX':   'existential there (like: "there is" ... think of it like "there exists")',
    'FW':   'foreign word',
    'IN':   'preposition/subordinating conjunction',
    'JJ':   'adjective "big"',
    'JJR':  'adjective, comparative "bigger"',
    'JJS':  'adjective, superlative "biggest"',
    'LS':   'list marker 1)',
    'MD':   'modal could, will',
    'NN':   'noun, singular "desk"',
    'NNS':  'noun plural "desks"',
    'NNP':  'proper noun, singular "Harrison"',
    'NNPS': 'proper noun, plural "Americans"',
    'PDT':  'predeterminer "all the kids"',
    'POS':  'possessive ending parent"s',
    'PRP':  'personal pronoun I, he, she',
    'PRP$': 'possessive pronoun my, his, hers',
    'RB':   'adverb very, silently,',
    'RBR':  'adverb, comparative better',
    'RBS':  'adverb, superlative best',
    'RP':   'particle give up',
    'TO':   'to go "to" the store.',
    'UH':   'interjection errrrrrrrm',
    'VB':   'verb, base form take',
    'VBD':  'verb, past tense took',
    'VBG':  'verb, gerund/present participle taking',
    'VBN':  'verb, past participle taken',
    'VBP':  'verb, sing. present, non-3d take',
    'VBZ':  'verb, 3rd person sing. present takes',
    'WDT':  'wh-determiner which',
    'WP':   'wh-pronoun who, what',
    'WP$':  'possessive wh-pronoun whose',
    'WRB':  'wh-abverb where, when',
}

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
## nltk
tagged = nltk.pos_tag(tokens)

for i, t in enumerate(tagged[:25]):
    print('%2d|%-12r : %-4s %s' % (i+1, t[0], t[1], (pos_list[t[1]] if t[1] in pos_list else '-')))
# Out:
#  1|'USS'        : NNP  proper noun, singular "Harrison"
#  2|'Enterprise' : NNP  proper noun, singular "Harrison"
#  3|'('          : (    -
#  4|'NCC-1701-D' : NNP  proper noun, singular "Harrison"
#  5|')'          : )    -
#  6|"''"         : ''   -
#  7|'For'        : IN   preposition/subordinating conjunction
#  8|'five'       : CD   cardinal digit
#  9|'hundred'    : CD   cardinal digit
# 10|'years'      : NNS  noun plural "desks"
# 11|','          : ,    -
# 12|'every'      : DT   determiner
# 13|'ship'       : NN   noun, singular "desk"
# 14|'that'       : WDT  wh-determiner which
# 15|'has'        : VBZ  verb, 3rd person sing. present takes
# 16|'borne'      : VBN  verb, past participle taken
# 17|'the'        : DT   determiner
# 18|'name'       : NN   noun, singular "desk"
# 19|'of'         : IN   preposition/subordinating conjunction
# 20|'the'        : DT   determiner
# 21|'Enterprise' : NNP  proper noun, singular "Harrison"
# 22|'has'        : VBZ  verb, 3rd person sing. present takes
# 23|'become'     : VBN  verb, past participle taken
# 24|'a'          : DT   determiner
# 25|'legend'     : NN   noun, singular "desk"

# %% [markdown]
# ### Stemming

# %%
## nltk
ps = nltk.porter.PorterStemmer()
stemmed = ' '.join([ps.stem(word) for word in text.split()])

# %% [markdown]
# ### Lemmatisation

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
## nltk
wl = nltk.stem.WordNetLemmatizer()
lemma = ' '.join([wl.lemmatize(word) for word in text.split()])

# %%
## nltk
dot = stemmed.find('.') + 1
sl = stemmed[:dot].split()
dot = lemma.find('.') + 1
ll = lemma[:dot].split()

print('i | Stem           Lemma')
print('--| -------------- ------------')
for i, p in enumerate(zip(sl, ll)):
    print('%2d| %-12r   %-12r' % (i+1, p[0], p[1]))
# Out:
# i | Stem           Lemma
# --| -------------- ------------
#  1| 'uss'          'USS'
#  2| 'enterpris'    'Enterprise'
#  3| '(ncc-1701-d)'   '(NCC-1701-D)'
#  4| '"for'         '"For'
#  5| 'five'         'five'
#  6| 'hundr'        'hundred'
#  7| 'years,'       'years,'
#  8| 'everi'        'every'
#  9| 'ship'         'ship'
# 10| 'that'         'that'
# 11| 'ha'           'ha'
# 12| 'born'         'borne'
# 13| 'the'          'the'
# 14| 'name'         'name'
# 15| 'of'           'of'
# 16| 'the'          'the'
# 17| 'enterpris'    'Enterprise'
# 18| 'ha'           'ha'
# 19| 'becom'        'become'
# 20| 'a'            'a'
# 21| 'legend.'      'legend.'

# %%
plot_words(stemmed.split())

# %%
plot_words(lemma.split())

# %% [markdown]
# ### Entity recognition

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
## nltk
entities = nltk.chunk.ne_chunk(tagged)

for e in entities:
    s = re.sub(r'[\(\)]', '', str(e))
    if s.find('/NNP') > 0:
        t = s.split()[0]
        n = ' '.join([re.sub(r'/NNP', '', x) for x in s.split()[1:]])
        print('%-12s: %s' % (t, n))
# Out:
# ORGANIZATION: USS Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS Enterprise
# PERSON      : United Federation
# ORGANIZATION: Planets Galaxy
# PERSON      : Starfleet
# ORGANIZATION: Enterprise
# ORGANIZATION: Federation
# ORGANIZATION: Battle
# GPE         : Veridian
# ORGANIZATION: Utopia Planitia Fleet
# PERSON      : Mars
# ORGANIZATION: Solar
# ORGANIZATION: Commander Orfil Quinteros
# PERSON      : Brahms
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS Pegasus
# ORGANIZATION: Utopia Planitia
# PERSON      : Walter Pierce
# PERSON      : Marla Finn
# PERSON      : William Hodges
# PERSON      : Pierce
# ORGANIZATION: Enterprise
# PERSON      : Mars
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# FACILITY    : Earth Station McKinley
# PERSON      : Captain Jean-Luc Picard
# ORGANIZATION: Rear Admiral Norah Satie
# ORGANIZATION: Commander Riker
# ORGANIZATION: Enterprise
# PERSON      : Picard
# PERSON      : Deep Space
# GPE         : Starfleet
# PERSON      : Captain Benjamin Sisko
# ORGANIZATION: Enterprise
# GPE         : Worf
# ORGANIZATION: Enterprise
# PERSON      : Picard
# ORGANIZATION: Class Sovereign
# ORGANIZATION: Enterprise
# PERSON      : Picard
# ORGANIZATION: CO
# GPE         : Worf
# ORGANIZATION: DS9

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
